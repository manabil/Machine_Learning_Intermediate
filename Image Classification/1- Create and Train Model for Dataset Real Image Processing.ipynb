# %% [markdown]
# <a href="https://colab.research.google.com/github/manabil/Machine_Learning_Intermediate/blob/main/Image%20Classification/1-%20Create%20and%20Train%20Model%20for%20Dataset%20Real%20Image%20Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget --no-check-certificate \
    https://github.com/dicodingacademy/assets/raw/main/ml_pengembangan_academy/Chessman-image-dataset.zip \
    -O /tmp/Chessman-image-dataset.zip
# Out:
# --2022-08-30 05:05:24--  https://github.com/dicodingacademy/assets/raw/main/ml_pengembangan_academy/Chessman-image-dataset.zip
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dicodingacademy/assets/main/ml_pengembangan_academy/Chessman-image-dataset.zip [following]
# --2022-08-30 05:05:24--  https://raw.githubusercontent.com/dicodingacademy/assets/main/ml_pengembangan_academy/Chessman-image-dataset.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60684125 (58M) [application/zip]
# Saving to: ‘/tmp/Chessman-image-dataset.zip’
#
# /tmp/Chessman-image 100%[===================>]  57.87M   359MB/s    in 0.2s
#
# 2022-08-30 05:05:28 (359 MB/s) - ‘/tmp/Chessman-image-dataset.zip’ saved [60684125/60684125]

# %%
import os
import zipfile
local_zip = '/tmp/Chessman-image-dataset.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
os.listdir('/tmp/Chessman-image-dataset/Chess')
# Out:
# ['Pawn', 'King', 'Knight', 'Bishop', 'Queen', 'Rook']

# %%
print('total pawn images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Pawn')))
print('total King images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/King')))
print('total Knight images :', len(os.listdir('/tmp/Chessman-image-dataset/Chess/Knight')))
# Out:
# total pawn images : 107
# total King images : 76
# total Knight images : 106

# %%
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
img = image.load_img('/tmp/Chessman-image-dataset/Chess/King/00000145.png')
imgplot = plt.imshow(img)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
    
    
train_dir = os.path.join('/tmp/Chessman-image-dataset/Chess')
train_datagen = ImageDataGenerator(rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    shear_range=0.2,
    fill_mode = 'nearest',
    validation_split=0.1) # set validation split

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150, 150),
    batch_size=8,
    class_mode='categorical',
    subset='training') # set as training data
validation_generator = train_datagen.flow_from_directory(
    train_dir, # same directory as training data
    target_size=(150, 150),
    batch_size=16,
    class_mode='categorical',
    subset='validation')
# Out:
# Found 499 images belonging to 6 classes.
# Found 52 images belonging to 6 classes.

# %%
import tensorflow as tf
model = tf.keras.models.Sequential([
    # Note the input shape is the desired size of the image 150x150 with 3 bytes color
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),  
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'), 
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),  
    # Flatten the results to feed into a DNN
    tf.keras.layers.Flatten(), 
    # 512 neuron hidden layer
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(6, activation='softmax')  
])

# %%
model.compile(optimizer=tf.optimizers.Adam(),
                loss='categorical_crossentropy',
                metrics = ['accuracy'])

# %%
history = model.fit(train_generator,
                                validation_data=validation_generator,
                                epochs=50,
                                verbose=2)
# Out:
# Epoch 1/50
# 63/63 - 23s - loss: 1.9343 - accuracy: 0.1904 - val_loss: 1.7898 - val_accuracy: 0.1923 - 23s/epoch - 359ms/step
# Epoch 2/50
# 63/63 - 10s - loss: 1.7899 - accuracy: 0.1844 - val_loss: 1.7857 - val_accuracy: 0.1923 - 10s/epoch - 158ms/step
# Epoch 3/50
# 63/63 - 10s - loss: 1.7949 - accuracy: 0.1844 - val_loss: 1.7841 - val_accuracy: 0.1731 - 10s/epoch - 156ms/step
# Epoch 4/50
# 63/63 - 9s - loss: 1.7848 - accuracy: 0.1924 - val_loss: 1.7820 - val_accuracy: 0.1923 - 9s/epoch - 148ms/step
# Epoch 5/50
# 63/63 - 9s - loss: 1.7790 - accuracy: 0.2004 - val_loss: 1.7770 - val_accuracy: 0.2308 - 9s/epoch - 147ms/step
# Epoch 6/50
# 63/63 - 9s - loss: 1.7451 - accuracy: 0.2325 - val_loss: 1.7925 - val_accuracy: 0.2692 - 9s/epoch - 147ms/step
# Epoch 7/50
# 63/63 - 9s - loss: 1.7191 - accuracy: 0.2806 - val_loss: 1.7346 - val_accuracy: 0.2692 - 9s/epoch - 148ms/step
# Epoch 8/50
# 63/63 - 9s - loss: 1.6901 - accuracy: 0.2745 - val_loss: 1.8256 - val_accuracy: 0.3269 - 9s/epoch - 146ms/step
# Epoch 9/50
# 63/63 - 9s - loss: 1.6686 - accuracy: 0.3206 - val_loss: 1.7366 - val_accuracy: 0.2885 - 9s/epoch - 146ms/step
# Epoch 10/50
# 63/63 - 9s - loss: 1.6116 - accuracy: 0.3367 - val_loss: 1.6985 - val_accuracy: 0.3462 - 9s/epoch - 147ms/step
# Epoch 11/50
# 63/63 - 9s - loss: 1.5927 - accuracy: 0.3467 - val_loss: 1.6318 - val_accuracy: 0.3462 - 9s/epoch - 148ms/step
# Epoch 12/50
# 63/63 - 9s - loss: 1.5591 - accuracy: 0.3788 - val_loss: 1.5904 - val_accuracy: 0.3846 - 9s/epoch - 147ms/step
# Epoch 13/50
# 63/63 - 9s - loss: 1.5103 - accuracy: 0.3908 - val_loss: 1.5906 - val_accuracy: 0.2692 - 9s/epoch - 148ms/step
# Epoch 14/50
# 63/63 - 10s - loss: 1.4227 - accuracy: 0.4329 - val_loss: 1.6285 - val_accuracy: 0.3269 - 10s/epoch - 161ms/step
# Epoch 15/50
# 63/63 - 9s - loss: 1.4321 - accuracy: 0.4128 - val_loss: 1.5927 - val_accuracy: 0.3654 - 9s/epoch - 147ms/step
# Epoch 16/50
# 63/63 - 9s - loss: 1.3300 - accuracy: 0.4910 - val_loss: 1.6495 - val_accuracy: 0.3846 - 9s/epoch - 146ms/step
# Epoch 17/50
# 63/63 - 9s - loss: 1.3717 - accuracy: 0.4890 - val_loss: 1.6580 - val_accuracy: 0.3077 - 9s/epoch - 147ms/step
# Epoch 18/50
# 63/63 - 9s - loss: 1.2993 - accuracy: 0.4870 - val_loss: 1.5455 - val_accuracy: 0.4038 - 9s/epoch - 148ms/step
# Epoch 19/50
# 63/63 - 9s - loss: 1.2563 - accuracy: 0.5291 - val_loss: 1.6218 - val_accuracy: 0.3077 - 9s/epoch - 146ms/step
# Epoch 20/50
# 63/63 - 9s - loss: 1.1770 - accuracy: 0.5291 - val_loss: 1.4612 - val_accuracy: 0.4038 - 9s/epoch - 149ms/step
# Epoch 21/50
# 63/63 - 9s - loss: 1.1655 - accuracy: 0.5110 - val_loss: 1.4051 - val_accuracy: 0.4808 - 9s/epoch - 150ms/step
# Epoch 22/50
# 63/63 - 9s - loss: 1.1117 - accuracy: 0.5932 - val_loss: 1.6425 - val_accuracy: 0.3846 - 9s/epoch - 148ms/step
# Epoch 23/50
# 63/63 - 9s - loss: 1.1673 - accuracy: 0.5391 - val_loss: 1.5876 - val_accuracy: 0.3846 - 9s/epoch - 146ms/step
# Epoch 24/50
# 63/63 - 9s - loss: 1.0626 - accuracy: 0.5992 - val_loss: 1.5700 - val_accuracy: 0.4231 - 9s/epoch - 146ms/step
# Epoch 25/50
# 63/63 - 9s - loss: 1.0282 - accuracy: 0.6172 - val_loss: 1.4790 - val_accuracy: 0.3654 - 9s/epoch - 149ms/step
# Epoch 26/50
# 63/63 - 9s - loss: 1.0651 - accuracy: 0.6052 - val_loss: 1.3947 - val_accuracy: 0.4423 - 9s/epoch - 145ms/step
# Epoch 27/50
# 63/63 - 9s - loss: 0.9318 - accuracy: 0.6513 - val_loss: 1.6018 - val_accuracy: 0.3462 - 9s/epoch - 144ms/step
# Epoch 28/50
# 63/63 - 9s - loss: 0.9526 - accuracy: 0.6253 - val_loss: 1.7178 - val_accuracy: 0.3654 - 9s/epoch - 146ms/step
# Epoch 29/50
# 63/63 - 9s - loss: 0.9259 - accuracy: 0.6493 - val_loss: 1.5868 - val_accuracy: 0.4038 - 9s/epoch - 145ms/step
# Epoch 30/50
# 63/63 - 9s - loss: 0.8980 - accuracy: 0.6733 - val_loss: 1.5230 - val_accuracy: 0.4231 - 9s/epoch - 146ms/step
# Epoch 31/50
# 63/63 - 9s - loss: 0.8277 - accuracy: 0.6954 - val_loss: 1.7459 - val_accuracy: 0.3462 - 9s/epoch - 145ms/step
# Epoch 32/50
# 63/63 - 9s - loss: 0.7756 - accuracy: 0.7214 - val_loss: 1.7110 - val_accuracy: 0.3654 - 9s/epoch - 144ms/step
# Epoch 33/50
# 63/63 - 9s - loss: 0.8179 - accuracy: 0.7054 - val_loss: 1.5165 - val_accuracy: 0.4423 - 9s/epoch - 144ms/step
# Epoch 34/50
# 63/63 - 9s - loss: 0.7657 - accuracy: 0.6974 - val_loss: 1.7272 - val_accuracy: 0.4231 - 9s/epoch - 144ms/step
# Epoch 35/50
# 63/63 - 9s - loss: 0.8805 - accuracy: 0.6954 - val_loss: 1.5368 - val_accuracy: 0.4423 - 9s/epoch - 145ms/step
# Epoch 36/50
# 63/63 - 9s - loss: 0.7011 - accuracy: 0.7275 - val_loss: 1.9338 - val_accuracy: 0.3654 - 9s/epoch - 145ms/step
# Epoch 37/50
# 63/63 - 10s - loss: 0.6660 - accuracy: 0.7555 - val_loss: 1.7232 - val_accuracy: 0.4038 - 10s/epoch - 161ms/step
# Epoch 38/50
# 63/63 - 9s - loss: 0.6224 - accuracy: 0.7735 - val_loss: 1.5535 - val_accuracy: 0.3654 - 9s/epoch - 146ms/step
# Epoch 39/50
# 63/63 - 9s - loss: 0.6517 - accuracy: 0.7675 - val_loss: 1.7136 - val_accuracy: 0.3846 - 9s/epoch - 147ms/step
# Epoch 40/50
# 63/63 - 9s - loss: 0.6327 - accuracy: 0.7695 - val_loss: 1.5755 - val_accuracy: 0.4038 - 9s/epoch - 146ms/step
# Epoch 41/50
# 63/63 - 9s - loss: 0.5755 - accuracy: 0.8096 - val_loss: 1.6837 - val_accuracy: 0.3846 - 9s/epoch - 147ms/step
# Epoch 42/50
# 63/63 - 9s - loss: 0.5539 - accuracy: 0.7956 - val_loss: 1.6562 - val_accuracy: 0.2885 - 9s/epoch - 147ms/step
# Epoch 43/50
# 63/63 - 9s - loss: 0.5665 - accuracy: 0.7836 - val_loss: 1.7406 - val_accuracy: 0.4038 - 9s/epoch - 146ms/step
# Epoch 44/50
# 63/63 - 9s - loss: 0.5710 - accuracy: 0.8076 - val_loss: 2.0298 - val_accuracy: 0.2692 - 9s/epoch - 145ms/step
# Epoch 45/50
# 63/63 - 9s - loss: 0.6287 - accuracy: 0.7495 - val_loss: 1.5723 - val_accuracy: 0.4423 - 9s/epoch - 146ms/step
# Epoch 46/50
# 63/63 - 9s - loss: 0.4789 - accuracy: 0.8136 - val_loss: 2.0529 - val_accuracy: 0.3462 - 9s/epoch - 148ms/step
# Epoch 47/50
# 63/63 - 9s - loss: 0.5038 - accuracy: 0.8056 - val_loss: 1.6317 - val_accuracy: 0.4615 - 9s/epoch - 146ms/step
# Epoch 48/50
# 63/63 - 9s - loss: 0.5169 - accuracy: 0.8016 - val_loss: 1.9146 - val_accuracy: 0.4038 - 9s/epoch - 147ms/step
# Epoch 49/50
# 63/63 - 10s - loss: 0.5411 - accuracy: 0.8156 - val_loss: 1.5998 - val_accuracy: 0.4038 - 10s/epoch - 160ms/step
# Epoch 50/50
# 63/63 - 9s - loss: 0.4546 - accuracy: 0.8537 - val_loss: 1.9127 - val_accuracy: 0.4038 - 9s/epoch - 145ms/step

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Akurasi Model')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
